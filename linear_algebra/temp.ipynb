# %%
from plot_helper import *

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import scipy as sp
import scipy.linalg
import sympy as sy # 행렬 기호 예쁘게 나오는 lib

sy.init_printing() # 수식을 보기좋게 출력하는 함수를 sy에서 호출
np.set_printoptions(precision=3) # 소수점 3째자리까지
np.set_printoptions(suppress=True) # 3째자리 뒤에는 막기

# %%
vectors = [(2,2)]
tails = [(-3,-2),(-3,1),(0,0), (1,-3)]
plot_vector(vectors, tails)
pyplot.title("title")
# Out:
# Text(0.5, 1.0, 'title')

# %%
i = np.array((1,0))
j = np.array((0,1))

vec = 3*i + 2*j
vectors = [i, j, 3*i, 2*j, vec]
plot_vector(vectors)
pyplot.title("title")
# Out:
# Text(0.5, 1.0, 'title')

# %%
from numpy.random import randint

vectors = []
i = numpy.array((-2,1))
j = numpy.array((-1,0.5))

for _ in range (1000):
    m = randint(-10,11) 
    n = randint(-10,11)
    vectors.append(m*i + n*j)
    
plot_vector(vectors)

# %%
#3d 로 프린트 하기 위한 사전 작업(회색 부분) 이건 거의 정형화 되어있음
fig = plt.figure(figsize = (8, 8))       # figsize는 optional
ax = fig.add_subplot(projection = '3d')

x2 = np.linspace(-2, 2, 10)  # -2부터 2까지 10개 array 만들기
x3 = np.linspace(-2, 2, 10)
X2, X3 = np.meshgrid(x2, x3) # array 로 정사각형 만들기
X1 = 3*X2 + 2*X3
# matplotlib의 함수 와이어로 프레임을 잡기
ax.plot_wireframe(X1, X2, X3, linewidth = 1.5, color = 'g', alpha = 0.6)

plt.show(
